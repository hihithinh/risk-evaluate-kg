# %%
import pandas as pd

df = pd.read_csv('raw_financial_data.csv')

# %%
column_mapping = {
"ticker": "Mã cổ phiếu",
"yearReport": "Năm báo cáo",
"lengthReport": "Kỳ báo cáo (quý/năm)",
"Revenue YoY (%)": "Tăng trưởng doanh thu (%)",
"Revenue (Bn. VND)": "Doanh thu (Tỷ VND)",
"Attribute to parent company (Bn. VND)": "LN thuộc cổ đông công ty mẹ (Tỷ VND)",
"Attribute to parent company YoY (%)": "Tăng trưởng LN công ty mẹ (%)",
"Financial Income": "Doanh thu tài chính",
"Interest Expenses": "Chi phí lãi vay",
"Sales": "Doanh thu bán hàng",
"Sales deductions": "Giảm trừ doanh thu",
"Net Sales": "Doanh thu thuần",
"Cost of Sales": "Giá vốn hàng bán",
"Gross Profit": "Lợi nhuận gộp",
"Financial Expenses": "Chi phí tài chính",
"Gain/(loss) from joint ventures": "Lãi/lỗ từ liên doanh liên kết",
"Selling Expenses": "Chi phí bán hàng",
"General & Admin Expenses": "Chi phí quản lý doanh nghiệp",
"Operating Profit/Loss": "Lợi nhuận hoạt động",
"Other income": "Thu nhập khác",
"Net income from associated companies": "LN từ công ty liên kết",
"Other Income/Expenses": "Thu/chi khác",
"Net other income/expenses": "Thu nhập khác thuần",
"Profit before tax": "Lợi nhuận trước thuế",
"Business income tax - current": "Thuế TNDN hiện hành",
"Business income tax - deferred": "Thuế TNDN hoãn lại",
"Net Profit For the Year": "Lợi nhuận sau thuế",
"Minority Interest": "Lợi ích cổ đông thiểu số",
"Attributable to parent company": "LN thuộc cổ đông công ty mẹ",
"symbol": "Mã chứng khoán",
"report": "Loại báo cáo",

"CURRENT ASSETS (Bn. VND)": "Tài sản ngắn hạn (Tỷ VND)",
"Cash and cash equivalents (Bn. VND)": "Tiền và tương đương tiền (Tỷ VND)",
"Short-term investments (Bn. VND)": "Đầu tư ngắn hạn (Tỷ VND)",
"Accounts receivable (Bn. VND)": "Khoản phải thu (Tỷ VND)",
"Net Inventories": "Hàng tồn kho thuần",
"Other current assets": "Tài sản ngắn hạn khác",
"LONG-TERM ASSETS (Bn. VND)": "Tài sản dài hạn (Tỷ VND)",
"Long-term loans receivables (Bn. VND)": "Cho vay dài hạn (Tỷ VND)",
"Fixed assets (Bn. VND)": "Tài sản cố định (Tỷ VND)",
"Investment in properties": "Bất động sản đầu tư",
"Long-term investments (Bn. VND)": "Đầu tư dài hạn (Tỷ VND)",
"Goodwill": "Lợi thế thương mại",
"Other non-current assets": "Tài sản dài hạn khác",
"TOTAL ASSETS (Bn. VND)": "Tổng tài sản (Tỷ VND)",

"LIABILITIES (Bn. VND)": "Tổng nợ phải trả (Tỷ VND)",
"Current liabilities (Bn. VND)": "Nợ ngắn hạn (Tỷ VND)",
"Long-term liabilities (Bn. VND)": "Nợ dài hạn (Tỷ VND)",
"OWNER'S EQUITY(Bn.VND)": "Vốn chủ sở hữu (Tỷ VND)",
"Capital and reserves (Bn. VND)": "Vốn và các quỹ (Tỷ VND)",
"Undistributed earnings (Bn. VND)": "Lợi nhuận chưa phân phối (Tỷ VND)",
"Budget sources and other funds": "Nguồn vốn ngân sách và quỹ khác",
"MINORITY INTERESTS": "Lợi ích cổ đông thiểu số",
"TOTAL RESOURCES (Bn. VND)": "Tổng nguồn vốn (Tỷ VND)",

"Prepayments to suppliers (Bn. VND)": "Trả trước cho người bán (Tỷ VND)",
"Short-term loans receivables (Bn. VND)": "Cho vay ngắn hạn (Tỷ VND)",
"Inventories, Net (Bn. VND)": "Hàng tồn kho thuần (Tỷ VND)",
"Other current assets (Bn. VND)": "Tài sản ngắn hạn khác (Tỷ VND)",
"Investment and development funds (Bn. VND)": "Quỹ đầu tư phát triển (Tỷ VND)",
"Common shares (Bn. VND)": "Cổ phiếu phổ thông (Tỷ VND)",
"Paid-in capital (Bn. VND)": "Vốn góp (Tỷ VND)",
"Long-term borrowings (Bn. VND)": "Vay dài hạn (Tỷ VND)",
"Advances from customers (Bn. VND)": "Người mua trả tiền trước (Tỷ VND)",
"Short-term borrowings (Bn. VND)": "Vay ngắn hạn (Tỷ VND)",
"Good will (Bn. VND)": "Lợi thế thương mại (Tỷ VND)",
"Long-term prepayments (Bn. VND)": "Trả trước dài hạn (Tỷ VND)",
"Other long-term assets (Bn. VND)": "Tài sản dài hạn khác (Tỷ VND)",
"Other long-term receivables (Bn. VND)": "Phải thu dài hạn khác (Tỷ VND)",
"Long-term trade receivables (Bn. VND)": "Phải thu dài hạn (Tỷ VND)",

"Net Profit/Loss before tax": "Lợi nhuận trước thuế",
"Depreciation and Amortisation": "Khấu hao",
"Provision for credit losses": "Dự phòng tổn thất tín dụng",
"Unrealized foreign exchange gain/loss": "Lãi/lỗ tỷ giá chưa thực hiện",
"Profit/Loss from investing activities": "LN từ hoạt động đầu tư",
"Interest Expense": "Chi phí lãi vay",
"Interest income and dividends": "Thu lãi và cổ tức",
"Operating profit before changes in working capital": "LN trước thay đổi vốn lưu động",

"Increase/Decrease in receivables": "Tăng/giảm khoản phải thu",
"Increase/Decrease in inventories": "Tăng/giảm tồn kho",
"Increase/Decrease in payables": "Tăng/giảm khoản phải trả",
"Increase/Decrease in prepaid expenses": "Tăng/giảm chi phí trả trước",
"Interest paid": "Lãi vay đã trả",
"Business Income Tax paid": "Thuế TNDN đã nộp",
"Other receipts from operating activities": "Thu khác từ HĐKD",
"Other payments on operating activities": "Chi khác từ HĐKD",
"Net cash inflows/outflows from operating activities": "Lưu chuyển tiền thuần HĐKD",

"Purchase of fixed assets": "Mua tài sản cố định",
"Proceeds from disposal of fixed assets": "Thu từ thanh lý TSCĐ",
"Loans granted, purchases of debt instruments (Bn. VND)": "Cho vay/mua công cụ nợ (Tỷ VND)",
"Collection of loans, proceeds from sales of debts instruments (Bn. VND)": "Thu hồi cho vay/bán công cụ nợ (Tỷ VND)",
"Investment in other entities": "Đầu tư vào đơn vị khác",
"Proceeds from divestment in other entities": "Thu từ thoái vốn",
"Gain on Dividend": "Thu cổ tức",
"Net Cash Flows from Investing Activities": "Lưu chuyển tiền thuần HĐ đầu tư",

"Increase in charter captial": "Tăng vốn điều lệ",
"Payments for share repurchases": "Mua lại cổ phiếu",
"Proceeds from borrowings": "Thu từ vay",
"Repayment of borrowings": "Trả nợ vay",
"Finance lease principal payments": "Trả gốc thuê tài chính",
"Dividends paid": "Cổ tức đã trả",
"Cash flows from financial activities": "Lưu chuyển tiền HĐ tài chính",
"Net increase/decrease in cash and cash equivalents": "Tăng/giảm tiền thuần",
"Cash and cash equivalents": "Tiền và tương đương tiền",
"Foreign exchange differences Adjustment": "Điều chỉnh chênh lệch tỷ giá",
"Cash and Cash Equivalents at the end of period": "Tiền cuối kỳ",

"Interest and Similar Income": "Thu nhập lãi và tương tự",
"Interest and Similar Expenses": "Chi phí lãi và tương tự",
"Net Interest Income": "Thu nhập lãi thuần",
"Fees and Comission Income": "Thu phí và hoa hồng",
"Fees and Comission Expenses": "Chi phí phí và hoa hồng",
"Net Fee and Commission Income": "Thu phí thuần",
"Net gain (loss) from foreign currency and gold dealings": "Lãi/lỗ kinh doanh ngoại tệ và vàng",
"Net gain (loss) from trading of trading securities": "Lãi/lỗ chứng khoán kinh doanh",
"Net gain (loss) from disposal of investment securities": "Lãi/lỗ bán chứng khoán đầu tư",
"Net Other income/(expenses)": "Thu nhập khác thuần",
"Other expenses": "Chi phí khác",
"Net Other income/expenses": "Thu nhập khác thuần",
"Dividends received": "Cổ tức nhận được",
"Total operating revenue": "Tổng thu nhập hoạt động",
"Operating Profit before Provision": "LN hoạt động trước dự phòng",
"Tax For the Year": "Thuế trong năm",
"EPS_basis": "EPS cơ bản",

"Balances with the SBV": "Tiền gửi tại NHNN",
"Placements with and loans to other credit institutions": "Tiền gửi/cho vay TCTD khác",
"Trading Securities, net": "Chứng khoán kinh doanh thuần",
"Trading Securities": "Chứng khoán kinh doanh",
"Provision for diminution in value of Trading Securities": "Dự phòng giảm giá CK kinh doanh",
"Derivatives and other financial liabilities": "Công cụ phái sinh và nợ tài chính khác",
"Loans and advances to customers, net": "Cho vay khách hàng thuần",
"Loans and advances to customers": "Cho vay khách hàng",
"Less: Provision for losses on loans and advances to customers": "Dự phòng rủi ro cho vay",
"Investment Securities": "Chứng khoán đầu tư",
"Available-for Sales Securities": "CK sẵn sàng để bán",
"Held-to-Maturity Securities": "CK nắm giữ đến đáo hạn",
"Less: Provision for diminution in value of investment securities": "Dự phòng giảm giá CK đầu tư",
"Investment in joint ventures": "Đầu tư liên doanh",
"Investments in associate companies": "Đầu tư công ty liên kết",
"Less: Provision for diminuation in value of long term investments": "Dự phòng giảm giá đầu tư dài hạn",
"Tangible fixed assets": "TSCĐ hữu hình",
"Intagible fixed assets": "TSCĐ vô hình",
"Other Assets": "Tài sản khác",

"Due to Gov and borrowings from SBV": "Nợ Chính phủ/NHNN",
"Deposits and borrowings from other credit institutions": "Tiền gửi/vay TCTD khác",
"Deposits from customers": "Tiền gửi khách hàng",
"_Derivatives and other financial liabilities": "Phái sinh và nợ tài chính khác",
"Funds received from Gov, international and other institutions": "Vốn nhận từ Chính phủ/tổ chức khác",
"Convertible bonds/CDs and other valuable papers issued": "Trái phiếu chuyển đổi và giấy tờ có giá",
"Other liabilities": "Nợ phải trả khác",

"Capital": "Vốn",
"Reserves": "Các quỹ",
"Foreign Currency Difference reserve": "Quỹ chênh lệch tỷ giá",
"Difference upon Assets Revaluation": "Chênh lệch đánh giá lại tài sản",
"Other Reserves": "Quỹ khác",
"Profits from other activities": "LN từ hoạt động khác",
"Net Cash Flows from Operating Activities before BIT": "Lưu chuyển tiền trước lãi vay và thuế",
"Payment from reserves": "Chi từ quỹ",
"Convertible bonds (Bn. VND)": "Trái phiếu chuyển đổi (Tỷ VND)",
"_Increase/Decrease in receivables": "Tăng/giảm phải thu",
"_Increase/Decrease in payables": "Tăng/giảm phải trả",
"Profit/Loss from disposal of fixed assets": "Lãi/lỗ thanh lý TSCĐ",
"Leased assets": "Tài sản thuê"
}

# %%
cols = df.columns.tolist()
column_index = {col: idx for idx, col in enumerate(df.columns)}

for idx, col in enumerate(df.columns):
    print(idx, col)
# Out:
# 0 ticker
# 1 yearReport
# 2 lengthReport
# 3 Revenue YoY (%)
# 4 Revenue (Bn. VND)
# 5 Attribute to parent company (Bn. VND)
# 6 Attribute to parent company YoY (%)
# 7 Financial Income
# 8 Interest Expenses
# 9 Sales
# 10 Sales deductions
# 11 Net Sales
# 12 Cost of Sales
# 13 Gross Profit
# 14 Financial Expenses
# 15 Gain/(loss) from joint ventures
# 16 Selling Expenses
# 17 General & Admin Expenses
# 18 Operating Profit/Loss
# 19 Other income
# 20 Net income from associated companies
# 21 Other Income/Expenses
# 22 Net other income/expenses
# 23 Profit before tax
# 24 Business income tax - current
# 25 Business income tax - deferred
# 26 Net Profit For the Year
# 27 Minority Interest
# 28 Attributable to parent company
# 29 symbol
# 30 report
# 31 CURRENT ASSETS (Bn. VND)
# 32 Cash and cash equivalents (Bn. VND)
# 33 Short-term investments (Bn. VND)
# 34 Accounts receivable (Bn. VND)
# 35 Net Inventories
# 36 Other current assets
# 37 LONG-TERM ASSETS (Bn. VND)
# 38 Long-term loans receivables (Bn. VND)
# 39 Fixed assets (Bn. VND)
# 40 Investment in properties
# 41 Long-term investments (Bn. VND)
# 42 Goodwill
# 43 Other non-current assets
# 44 TOTAL ASSETS (Bn. VND)
# 45 LIABILITIES (Bn. VND)
# 46 Current liabilities (Bn. VND)
# 47 Long-term liabilities (Bn. VND)
# 48 OWNER'S EQUITY(Bn.VND)
# 49 Capital and reserves (Bn. VND)
# 50 Undistributed earnings (Bn. VND)
# 51 Budget sources and other funds
# 52 MINORITY INTERESTS
# 53 TOTAL RESOURCES (Bn. VND)
# 54 Prepayments to suppliers (Bn. VND)
# 55 Short-term loans receivables (Bn. VND)
# 56 Inventories, Net (Bn. VND)
# 57 Other current assets (Bn. VND)
# 58 Investment and development funds (Bn. VND)
# 59 Common shares (Bn. VND)
# 60 Paid-in capital (Bn. VND)
# 61 Long-term borrowings (Bn. VND)
# 62 Advances from customers (Bn. VND)
# 63 Short-term borrowings (Bn. VND)
# 64 Good will (Bn. VND)
# 65 Long-term prepayments (Bn. VND)
# 66 Other long-term assets (Bn. VND)
# 67 Other long-term receivables (Bn. VND)
# 68 Long-term trade receivables (Bn. VND)
# 69 Net Profit/Loss before tax
# 70 Depreciation and Amortisation
# 71 Provision for credit losses
# 72 Unrealized foreign exchange gain/loss
# 73 Profit/Loss from investing activities
# 74 Interest Expense
# 75 Interest income and dividends
# 76 Operating profit before changes in working capital
# 77 Increase/Decrease in receivables
# 78 Increase/Decrease in inventories
# 79 Increase/Decrease in payables
# 80 Increase/Decrease in prepaid expenses
# 81 Interest paid
# 82 Business Income Tax paid
# 83 Other receipts from operating activities
# 84 Other payments on operating activities
# 85 Net cash inflows/outflows from operating activities
# 86 Purchase of fixed assets
# 87 Proceeds from disposal of fixed assets
# 88 Loans granted, purchases of debt instruments (Bn. VND)
# 89 Collection of loans, proceeds from sales of debts instruments (Bn. VND)
# 90 Investment in other entities
# 91 Proceeds from divestment in other entities
# 92 Gain on Dividend
# 93 Net Cash Flows from Investing Activities
# 94 Increase in charter captial
# 95 Payments for share repurchases
# 96 Proceeds from borrowings
# 97 Repayment of borrowings
# 98 Finance lease principal payments
# 99 Dividends paid
# 100 Cash flows from financial activities
# 101 Net increase/decrease in cash and cash equivalents
# 102 Cash and cash equivalents
# 103 Foreign exchange differences Adjustment
# 104 Cash and Cash Equivalents at the end of period
# 105 Interest and Similar Income
# 106 Interest and Similar Expenses
# 107 Net Interest Income
# 108 Fees and Comission Income
# 109 Fees and Comission Expenses
# 110 Net Fee and Commission Income
# 111 Net gain (loss) from foreign currency and gold dealings
# 112 Net gain (loss) from trading of trading securities
# 113 Net gain (loss) from disposal of investment securities
# 114 Net Other income/(expenses)
# 115 Other expenses
# 116 Net Other income/expenses
# 117 Dividends received
# 118 Total operating revenue
# 119 Operating Profit before Provision
# 120 Tax For the Year
# 121 EPS_basis
# 122 Balances with the SBV
# 123 Placements with and loans to other credit institutions
# 124 Trading Securities, net
# 125 Trading Securities
# 126 Provision for diminution in value of Trading Securities
# 127 Derivatives and other financial liabilities
# 128 Loans and advances to customers, net
# 129 Loans and advances to customers
# 130 Less: Provision for losses on loans and advances to customers
# 131 Investment Securities
# 132 Available-for Sales Securities
# 133 Held-to-Maturity Securities
# 134 Less: Provision for diminution in value of investment securities
# 135 Investment in joint ventures
# 136 Investments in associate companies
# 137 Less: Provision for diminuation in value of long term investments
# 138 Tangible fixed assets
# 139 Intagible fixed assets
# 140 Other Assets
# 141 Due to Gov and borrowings from SBV
# 142 Deposits and borrowings from other credit institutions
# 143 Deposits from customers
# 144 _Derivatives and other financial liabilities
# 145 Funds received from Gov, international and other institutions
# 146 Convertible bonds/CDs and other valuable papers issued
# 147 Other liabilities
# 148 Capital
# 149 Reserves
# 150 Foreign Currency Difference reserve
# 151 Difference upon Assets Revaluation
# 152 Other Reserves
# 153 Profits from other activities
# 154 Net Cash Flows from Operating Activities before BIT
# 155 Payment from reserves
# 156 Convertible bonds (Bn. VND)
# 157 _Increase/Decrease in receivables
# 158 _Increase/Decrease in payables
# 159 Profit/Loss from disposal of fixed assets
# 160 Leased assets

# %%
# Tách từng report
df_income = df[df["report"] == "income_statement"].copy()
df_balance = df[df["report"] == "balance_sheet"].copy()
df_cash = df[df["report"] == "cash_flow"].copy()

# Drop các cột toàn NaN
df_income = df_income.dropna(axis=1, how="all")
df_balance = df_balance.dropna(axis=1, how="all")
df_cash = df_cash.dropna(axis=1, how="all")

# Lưu ra file
df_income.to_csv("income_statement_clean.csv", index=False)
df_balance.to_csv("balance_sheet_clean.csv", index=False)
df_cash.to_csv("cash_flow_clean.csv", index=False)

print("Đã tách và loại bỏ cột rỗng xong.")
# Out:
# Đã tách và loại bỏ cột rỗng xong.

# %%
df_balance.head()
# Out:
#    ticker  yearReport  lengthReport  Minority Interest symbol         report  \
# 52    HPG        2025             4                NaN    HPG  balance_sheet
# 53    HPG        2025             3                NaN    HPG  balance_sheet
# 54    HPG        2025             2                NaN    HPG  balance_sheet
# 55    HPG        2025             1                NaN    HPG  balance_sheet
# 56    HPG        2024             4                NaN    HPG  balance_sheet
#
#     CURRENT ASSETS (Bn. VND)  Cash and cash equivalents (Bn. VND)  \
# 52              1.036820e+14                         8.300890e+12
# 53              9.542599e+13                         9.092563e+12
# 54              9.761390e+13                         1.068802e+13
# 55              8.891420e+13                         7.459036e+12
# 56              8.667428e+13                         6.887646e+12
#
#     Short-term investments (Bn. VND)  Accounts receivable (Bn. VND)  ...  \
# 52                      1.948441e+13                   1.506470e+13  ...
# 53                      1.890395e+13                   1.372719e+13  ...
# 54                      1.758403e+13                   1.233493e+13  ...
# 55                      1.621251e+13                   1.085605e+13  ...
# 56                      1.897472e+13                   7.647800e+12  ...
#
#     Funds received from Gov, international and other institutions  \
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
#
#     Convertible bonds/CDs and other valuable papers issued  Other liabilities  \
# 52                                                NaN                     NaN
# 53                                                NaN                     NaN
# 54                                                NaN                     NaN
# 55                                                NaN                     NaN
# 56                                                NaN                     NaN
#
#     Capital  Reserves  Foreign Currency Difference reserve  \
# 52      NaN       NaN                                  NaN
# 53      NaN       NaN                                  NaN
# 54      NaN       NaN                                  NaN
# 55      NaN       NaN                                  NaN
# 56      NaN       NaN                                  NaN
#
#     Difference upon Assets Revaluation  Other Reserves  \
# 52                                 NaN             NaN
# 53                                 NaN             NaN
# 54                                 NaN             NaN
# 55                                 NaN             NaN
# 56                                 NaN             NaN
#
#     Convertible bonds (Bn. VND)  Leased assets
# 52                          NaN            NaN
# 53                          NaN            NaN
# 54                          NaN            NaN
# 55                          NaN            NaN
# 56                          NaN            NaN
#
# [5 rows x 77 columns]

# %%
# df_cash.head()
df_cash.loc[
    (df_cash["ticker"] == "HPG") &
    (df_cash["yearReport"] == 2022),
    ["Interest Expense","lengthReport"]
]
# Out:
#      Interest Expense  lengthReport
# 116      9.326520e+11             4
# 117      8.367005e+11             3
# 118      7.173527e+11             2
# 119      5.969329e+11             1

# %%
import numpy as np
keys = ["ticker", "yearReport", "lengthReport"]

# Tránh duplicate key trước khi merge
for name, d in {
    "income": df_income,
    "balance": df_balance,
    "cash": df_cash
}.items():
    dup = d.duplicated(subset=keys).sum()
    print(f"{name} duplicate rows:", dup)


# Chỉ giữ symbol ở balance 
df_income = df_income.drop(columns=["symbol"], errors="ignore")
df_cash = df_cash.drop(columns=["symbol"], errors="ignore")


df_merged = (
    df_balance
    .merge(df_income, on=keys, how="left", validate="one_to_one")
    .merge(df_cash, on=keys, how="left", validate="one_to_one")
)

print("Merged shape:", df_merged.shape)


def safe_divide(a, b):
    return np.where((b == 0) | (pd.isna(b)), np.nan, a / b)



# ----- A: Thanh khoản -----
df_merged["A1"] = safe_divide(
    df_merged["CURRENT ASSETS (Bn. VND)"],
    df_merged["Current liabilities (Bn. VND)"]
)

df_merged["A2"] = safe_divide(
    df_merged["CURRENT ASSETS (Bn. VND)"] -
    df_merged["Inventories, Net (Bn. VND)"],
    df_merged["Current liabilities (Bn. VND)"]
)

df_merged["A3"] = safe_divide(
    df_merged["Cash and cash equivalents (Bn. VND)"],
    df_merged["Current liabilities (Bn. VND)"]
)


# ----- B: Đòn bẩy -----
df_merged["B1"] = safe_divide(
    df_merged["LIABILITIES (Bn. VND)"],
    df_merged["TOTAL ASSETS (Bn. VND)"]
)

df_merged["B2"] = safe_divide(
    df_merged["LIABILITIES (Bn. VND)"],
    df_merged["OWNER'S EQUITY(Bn.VND)"]
)

df_merged["B3"] = safe_divide(
    df_merged["Profit before tax"] + df_merged["Interest Expenses"].abs(),
    df_merged["Interest Expenses"]
)


# ----- C: Hiệu quả -----
df_merged["C1"] = safe_divide(
    df_merged["Cost of Sales"].abs(),
    df_merged["Inventories, Net (Bn. VND)"]
)

df_merged["C2"] = safe_divide(
    df_merged["Accounts receivable (Bn. VND)"],
    df_merged["Net Sales"]
)

df_merged["C3"] = safe_divide(
    df_merged["Net Sales"],
    df_merged["Fixed assets (Bn. VND)"]
)


# ----- D: Sinh lời -----
df_merged["D1"] = safe_divide(
    df_merged["Net Profit For the Year"],
    df_merged["Net Sales"]
)

df_merged["D2"] = safe_divide(
    df_merged["Profit before tax"] + df_merged["Interest Expenses"].abs(),
    df_merged["TOTAL ASSETS (Bn. VND)"]
)

df_merged["D3"] = safe_divide(
    df_merged["Net Profit For the Year"],
    df_merged["TOTAL ASSETS (Bn. VND)"]
)


ratio_cols = [
    "ticker",
    "symbol",
    "yearReport",
    "lengthReport",
    "A1","A2","A3",
    "B1","B2","B3",
    "C1","C2","C3",
    "D1","D2","D3"
]

df_ratio = df_merged[ratio_cols]

df_ratio.to_csv("financial_ratios_A1_D3.csv", index=False)

print("Đã lưu file financial_ratios_A1_D3.csv")
# Out:
# income duplicate rows: 0
# balance duplicate rows: 0
# cash duplicate rows: 0
# Merged shape: (1476, 166)
# Đã lưu file financial_ratios_A1_D3.csv

# %%
df_merged.head()
# Out:
#   ticker  yearReport  lengthReport  Minority Interest_x symbol       report_x  \
# 0    HPG        2025             4                  NaN    HPG  balance_sheet
# 1    HPG        2025             3                  NaN    HPG  balance_sheet
# 2    HPG        2025             2                  NaN    HPG  balance_sheet
# 3    HPG        2025             1                  NaN    HPG  balance_sheet
# 4    HPG        2024             4                  NaN    HPG  balance_sheet
#
#    CURRENT ASSETS (Bn. VND)  Cash and cash equivalents (Bn. VND)  \
# 0              1.036820e+14                         8.300890e+12
# 1              9.542599e+13                         9.092563e+12
# 2              9.761390e+13                         1.068802e+13
# 3              8.891420e+13                         7.459036e+12
# 4              8.667428e+13                         6.887646e+12
#
#    Short-term investments (Bn. VND)  Accounts receivable (Bn. VND)  ...  \
# 0                      1.948441e+13                   1.506470e+13  ...
# 1                      1.890395e+13                   1.372719e+13  ...
# 2                      1.758403e+13                   1.233493e+13  ...
# 3                      1.621251e+13                   1.085605e+13  ...
# 4                      1.897472e+13                   7.647800e+12  ...
#
#          A3        B1        B2         B3        C1        C2        C3  \
# 0  0.088112  0.491241  0.965566  -4.720208  0.752092  0.326242  0.345612
# 1  0.109334  0.482003  0.930513  -6.698531  0.663814  0.377044  0.347693
# 2  0.123665  0.494851  0.979614 -12.323709  0.599604  0.343491  0.549906
# 3  0.096496  0.484418  0.939556  -7.123790  0.689249  0.288558  0.438286
# 4  0.091560  0.489297  0.958087  -6.843056  0.652188  0.221733  0.511520
#
#          D1        D2        D3
# 0  0.084206  0.022630  0.015076
# 1  0.110204  0.022100  0.016299
# 2  0.118754  0.022341  0.017606
# 3  0.089039  0.019517  0.014637
# 4  0.081459  0.017146  0.012515
#
# [5 rows x 178 columns]

# %%
df_ratio.head(20)
# Out:
#    ticker symbol  yearReport  lengthReport        A1        A2        A3  \
# 0     HPG    HPG        2025             4  1.100558  0.539120  0.088112
# 1     HPG    HPG        2025             3  1.147453  0.598224  0.109334
# 2     HPG    HPG        2025             2  1.129432  0.563636  0.123665
# 3     HPG    HPG        2025             1  1.150270  0.545939  0.096496
# 4     HPG    HPG        2024             4  1.152197  0.538144  0.091560
# 5     HPG    HPG        2024             3  1.171703  0.584985  0.123212
# 6     HPG    HPG        2024             2  1.148408  0.598391  0.177183
# 7     HPG    HPG        2024             1  1.185565  0.645356  0.156704
# 8     HPG    HPG        2023             4  1.156655  0.672434  0.171540
# 9     HPG    HPG        2023             3  1.224050  0.696930  0.151234
# 10    HPG    HPG        2023             2  1.236136  0.766439  0.192952
# 11    HPG    HPG        2023             1  1.257934  0.748427  0.115885
# 12    HPG    HPG        2022             4  1.290602  0.717915  0.133438
# 13    HPG    HPG        2022             3  1.335597  0.718206  0.163814
# 14    HPG    HPG        2022             2  1.284213  0.661267  0.217117
# 15    HPG    HPG        2022             1  1.386377  0.831171  0.263087
# 16    HPG    HPG        2021             4  1.281722  0.704940  0.305902
# 17    HPG    HPG        2021             3  1.332836  0.692906  0.185796
# 18    HPG    HPG        2021             2  1.188837  0.613829  0.211215
# 19    HPG    HPG        2021             1  1.241516  0.700795  0.272185
#
#           B1        B2         B3        C1        C2        C3        D1  \
# 0   0.491241  0.965566  -4.720208  0.752092  0.326242  0.345612  0.084206
# 1   0.482003  0.930513  -6.698531  0.663814  0.377044  0.347693  0.110204
# 2   0.494851  0.979614 -12.323709  0.599604  0.343491  0.549906  0.118754
# 3   0.484418  0.939556  -7.123790  0.689249  0.288558  0.438286  0.089039
# 4   0.489297  0.958087  -6.843056  0.652188  0.221733  0.511520  0.081459
# 5   0.471209  0.891108  -7.498360  0.721951  0.269198  0.495888  0.088987
# 6   0.473999  0.901137  -7.617618  0.848066  0.262740  0.564928  0.083922
# 7   0.476951  0.911868  -6.130771  0.623119  0.392356  0.434442  0.092997
# 8   0.452364  0.826032  -5.760671  0.863806  0.311255  0.477457  0.086348
# 9   0.424431  0.737412  -3.540053  0.736425  0.439056  0.391360  0.070227
# 10  0.444743  0.800969  -2.654619  0.815270  0.484760  0.427894  0.049085
# 11  0.450210  0.818875  -1.537640  0.720115  0.520150  0.380136  0.014413
# 12  0.435743  0.772243   1.228643  0.747636  0.383063  0.364601 -0.077394
# 13  0.466416  0.874119   0.553669  0.739240  0.352092  0.475475 -0.052362
# 14  0.518472  1.076723  -7.104864  0.529565  0.382703  0.534147  0.107492
# 15  0.467530  0.878041 -15.946578  0.844032  0.275276  0.627479  0.186261
# 16  0.490674  0.963380 -13.769288  0.828967  0.171373  0.645355  0.165942
# 17  0.517155  1.071057 -17.262224  0.581976  0.280712  0.567422  0.267645
# 18  0.537045  1.160037 -18.258827  0.593003  0.226266  0.518849  0.277495
# 19  0.523525  1.098747 -13.372699  0.825651  0.278560  0.461248  0.224704
#
#           D2        D3
# 0   0.022630  0.015076
# 1   0.022100  0.016299
# 2   0.022341  0.017606
# 3   0.019517  0.014637
# 4   0.017146  0.012515
# 5   0.018627  0.014295
# 6   0.020799  0.016067
# 7   0.019297  0.014208
# 8   0.021810  0.015811
# 9   0.017464  0.011529
# 10  0.015493  0.008215
# 11  0.008675  0.002185
# 12 -0.006727 -0.011734
# 13 -0.002520 -0.009715
# 14  0.024563  0.019386
# 15  0.051220  0.044156
# 16  0.048631  0.041627
# 17  0.066730  0.059268
# 18  0.068514  0.060980
# 19  0.059804  0.050406

# %%
import numpy as np

def get_data(ticker, year, quarter, column_name):
    
    row = df_merged[
        (df_merged["ticker"] == ticker) &
        (df_merged["yearReport"] == year) &
        (df_merged["lengthReport"] == quarter)
    ]

    if row.empty:
        return np.nan
    
    print("Value:", row.iloc[0][column_name])
    
    return row.iloc[0][column_name]

# %%
ratio_column_map = {

    # ===== A. Thanh toán =====
    "Tài sản ngắn hạn": "CURRENT ASSETS (Bn. VND)",
    "Nợ ngắn hạn": "Current liabilities (Bn. VND)",
    "Hàng tồn kho": "Inventories, Net (Bn. VND)",
    "Tiền và tương đương tiền": "Cash and cash equivalents (Bn. VND)",

    # ===== B. Cân đối vốn =====
    "Nợ phải trả": "LIABILITIES (Bn. VND)",
    "Tổng tài sản": "TOTAL ASSETS (Bn. VND)",
    "Vốn chủ sở hữu": "OWNER'S EQUITY(Bn.VND)",
    "Lợi nhuận trước thuế": "Profit before tax",
    "Chi phí lãi vay": "Interest Expenses",

    # ===== C. Hiệu quả hoạt động =====
    "Giá vốn hàng bán": "Cost of Sales",
    "Khoản phải thu": "Accounts receivable (Bn. VND)",
    "Doanh thu thuần": "Net Sales",
    "Tài sản cố định": "Fixed assets (Bn. VND)",

    # ===== D. Sinh lợi =====
    "Lợi nhuận sau thuế": "Net Profit For the Year"
}

# %%
import numpy as np

def get_value(data_source, ticker, year, quarter, column_name):
    df_filtered = data_source[
        (data_source['ticker'] == ticker) & 
        (data_source['yearReport'] == year) & 
        (data_source['lengthReport'] == quarter)
    ]
    
    if not df_filtered.empty:
        return df_filtered.iloc[0][column_name]
    else:
        return np.nan

# %%
# Kiểm tra dữ liệu

all_tickers = [
    "HPG", "VCB", "SSI", "VNM", "MWG",
    "FPT", "GAS", "VPB", "TCB", "MBB",
    "ACB", "VIC", "VHM", "BID", "CTG",
    "PNJ", "REE", "HDB", "VRE", "PLX",
    "POW", "BVH", "GVR", "KDH", "NVL",
    "PDR", "STB", "MSN", "SAB", "DGC"
]



tickers_to_test = [
    "HPG", "ACB", "VIC", "VHM", "BID", "CTG",
]

years = [2022, 2023, 2024, 2025, 2026]

quarters = [3]

for ticker in tickers_to_test:
    for year in years:
        for quarter in quarters:
            
            temp_data = {}
            
            for col_vn, col_en in ratio_column_map.items():
                temp_data[col_vn] = get_value(df_merged, ticker, year, int(quarter), col_en)

            
            # Nhóm A: Thanh toán
            tai_san_ngan_han         = temp_data["Tài sản ngắn hạn"]
            no_ngan_han              = temp_data["Nợ ngắn hạn"]
            hang_ton_kho             = temp_data["Hàng tồn kho"]
            tien_va_tuong_duong_tien = temp_data["Tiền và tương đương tiền"]

            # Nhóm B: Cân đối vốn
            no_phai_tra              = temp_data["Nợ phải trả"]
            tong_tai_san             = temp_data["Tổng tài sản"]
            von_chu_so_huu           = temp_data["Vốn chủ sở hữu"]
            loi_nhuan_truoc_thue     = temp_data["Lợi nhuận trước thuế"]
            chi_phi_lai_vay          = temp_data["Chi phí lãi vay"]

            print(f"\n=== Debug: B3 components ===")
            print(f"  Lợi nhuận trước thuế: {loi_nhuan_truoc_thue}")
            print(f"  Chi phí lãi vay: {chi_phi_lai_vay}")
            # Nhóm C: Hiệu quả hoạt động
            gia_von_hang_ban         = temp_data["Giá vốn hàng bán"]
            khoan_phai_thu           = temp_data["Khoản phải thu"]
            doanh_thu_thuan          = temp_data["Doanh thu thuần"]
            tai_san_co_dinh          = temp_data["Tài sản cố định"]

            # Nhóm D: Sinh lợi
            loi_nhuan_sau_thue       = temp_data["Lợi nhuận sau thuế"]

            
            def safe_div(a, b):
                try:
                    if a is None or b is None or b == 0:
                        return None
                    return a / b
                except:
                    return None


            # ================= A. Thanh toán =================
            A1_cal = safe_div(tai_san_ngan_han, no_ngan_han)

            A2_cal = safe_div(
                (tai_san_ngan_han - hang_ton_kho) if tai_san_ngan_han and hang_ton_kho else None,
                no_ngan_han
            )

            A3_cal = safe_div(tien_va_tuong_duong_tien, no_ngan_han)


            # ================= B. Cân đối vốn =================
            B1_cal = safe_div(no_phai_tra, tong_tai_san)

            B2_cal = safe_div(no_phai_tra, von_chu_so_huu)

            B3_cal = safe_div(loi_nhuan_truoc_thue, chi_phi_lai_vay)


            # ================= C. Hiệu quả hoạt động =================
            C1_cal = safe_div(gia_von_hang_ban, hang_ton_kho)

            C2_cal = safe_div(khoan_phai_thu, doanh_thu_thuan)

            C3_cal = safe_div(doanh_thu_thuan, tai_san_co_dinh)


            # ================= D. Sinh lợi =================
            D1_cal = safe_div(loi_nhuan_sau_thue, doanh_thu_thuan)

            D2_cal = safe_div(loi_nhuan_truoc_thue, tong_tai_san)

            D3_cal = safe_div(loi_nhuan_sau_thue, tong_tai_san)

            ratio_results = {
                "A1": A1_cal,
                "A2": A2_cal,
                "A3": A3_cal,
                "B1": B1_cal,
                "B2": B2_cal,
                "B3": B3_cal,
                "C1": C1_cal,
                "C2": C2_cal,
                "C3": C3_cal,
                "D1": D1_cal,
                "D2": D2_cal,
                "D3": D3_cal,
            }

            print(f"\n===== TEST {ticker} - Year {year} - Q{quarter} =====")

            all_pass = True

            for ratio_name, calculated_value in ratio_results.items():
                print(f"Testing {ratio_name}...")

                original_value = get_value(df_ratio, ticker, year, quarter, ratio_name)

                if calculated_value is None or original_value is None:
                    print(f"[SKIP] {ratio_name} - missing data")
                    continue

                if np.isclose(calculated_value, original_value, atol=1e-6):
                    print(f"[PASS] {ratio_name}")
                else:
                    if np.isnan(calculated_value) and np.isnan(original_value):
                        print(f"[PASS] {ratio_name} (both NaN)")
                    else:
                        print(f"[FAIL] {ratio_name}")
                        print(f"       Calculated : {calculated_value}")
                        print(f"       Original   : {original_value}")
                        print(f"       Diff       : {calculated_value - original_value}")
                        all_pass = False


            if all_pass:
                print(">>> ✅ ALL RATIOS MATCH")
            else:
                print(">>> ❌ SOME RATIOS FAILED")
# Out:
# === Debug: B3 components ===
#   Lợi nhuận trước thuế: -1299955296196.0
#   Chi phí lãi vay: -836700531276.0
#
# ===== TEST HPG - Year 2022 - Q3 =====
# Testing A1...
# [PASS] A1
# Testing A2...
# [PASS] A2
# Testing A3...
# [PASS] A3
# Testing B1...
# [PASS] B1
# Testing B2...
# [PASS] B2
# Testing B3...
# [FAIL] B3
#        Calculated : 1.5536685440052476
#        Original   : 0.5536685440052476
#        Diff       : 1.0
# Testing C1...
# [FAIL] C1
#        Calculated : -0.7392399127136892
#        Original   : 0.7392399127136892
#        Diff       : -1.4784798254273783
# Testing C2...
# [PASS] C2
# Testing C3...
# [PASS] C3
# Testing D1...
# [PASS] D1
# Testing D2...
# [FAIL] D2
#        Calculated : -0.00707246543963712
#        Original   : -0.002520358449426193
#        Diff       : -0.004552106990210927
# Testing D3...
# [PASS] D3
# >>> ❌ SOME RATIOS FAILED
#
# === Debug: B3 components ===
#   Lợi nhuận trước thuế: 2174230121892.0
#   Chi phí lãi vay: -855978191830.0
#
# ===== TEST HPG - Year 2023 - Q3 =====
# Testing A1...
# [PASS] A1
# Testing A2...
# [PASS] A2
# Testing A3...
# [PASS] A3
# Testing B1...
# [PASS] B1
# Testing B2...
# [PASS] B2
# Testing B3...
# [FAIL] B3
#        Calculated : -2.5400531726675215
#        Original   : -3.5400531726675215
#        Diff       : 1.0
# Testing C1...
# [FAIL] C1
#        Calculated : -0.7364250213001345
#        Original   : 0.7364250213001345
#        Diff       : -1.472850042600269
# Testing C2...
# [PASS] C2
# Testing C3...
# [PASS] C3
# Testing D1...
# [PASS] D1
# Testing D2...
# [FAIL] D2
#        Calculated : 0.012531079296349437
#        Original   : 0.01746447180607769
#        Diff       : -0.004933392509728253
# Testing D3...
# [PASS] D3
# >>> ❌ SOME RATIOS FAILED
#
# === Debug: B3 components ===
#   Lợi nhuận trước thuế: 3412385133844.0
#   Chi phí lãi vay: -525114798901.0
#
# ===== TEST HPG - Year 2024 - Q3 =====
# Testing A1...
# [PASS] A1
# Testing A2...
# [PASS] A2
# Testing A3...
# [PASS] A3
# Testing B1...
# [PASS] B1
# Testing B2...
# [PASS] B2
# Testing B3...
# [FAIL] B3
#        Calculated : -6.4983602461513135
#        Original   : -7.4983602461513135
#        Diff       : 1.0
# Testing C1...
# [FAIL] C1
#        Calculated : -0.7219507708682718
#        Original   : 0.7219507708682718
#        Diff       : -1.4439015417365435
# Testing C2...
# [PASS] C2
# Testing C3...
# [PASS] C3
# Testing D1...
# [PASS] D1
# Testing D2...
# [FAIL] D2
#        Calculated : 0.016142883548827463
#        Original   : 0.018627030770180443
#        Diff       : -0.00248414722135298
# Testing D3...
# [PASS] D3
# >>> ❌ SOME RATIOS FAILED
#
# === Debug: B3 components ===
#   Lợi nhuận trước thuế: 4628313172434.0
#   Chi phí lãi vay: -812194101705.0
#
# ===== TEST HPG - Year 2025 - Q3 =====
# Testing A1...
# [PASS] A1
# Testing A2...
# [PASS] A2
# Testing A3...
# [PASS] A3
# Testing B1...
# [PASS] B1
# Testing B2...
# [PASS] B2
# Testing B3...
# [FAIL] B3
#        Calculated : -5.698530884080548
#        Original   : -6.698530884080548
#        Diff       : 1.0
# Testing C1...
# [FAIL] C1
#        Calculated : -0.663813530598954
#        Original   : 0.663813530598954
#        Diff       : -1.327627061197908
# Testing C2...
# [PASS] C2
# Testing C3...
# [PASS] C3
# Testing D1...
# [PASS] D1
# Testing D2...
# [FAIL] D2
#        Calculated : 0.018801186216998996
#        Original   : 0.022100490300709784
#        Diff       : -0.0032993040837107877
# Testing D3...
# [PASS] D3
# >>> ❌ SOME RATIOS FAILED
#
# === Debug: B3 components ===
#   Lợi nhuận trước thuế: nan
#   Chi phí lãi vay: nan
#
# ===== TEST HPG - Year 2026 - Q3 =====
# Testing A1...
# [PASS] A1 (both NaN)
# Testing A2...
# [PASS] A2 (both NaN)
# Testing A3...
# [PASS] A3 (both NaN)
# Testing B1...
# [PASS] B1 (both NaN)
# Testing B2...
# [PASS] B2 (both NaN)
# Testing B3...
# [PASS] B3 (both NaN)
# Testing C1...
# [PASS] C1 (both NaN)
# Testing C2...
# [PASS] C2 (both NaN)
# Testing C3...
# [PASS] C3 (both NaN)
# Testing D1...
# [PASS] D1 (both NaN)
# Testing D2...
# [PASS] D2 (both NaN)
# Testing D3...
# [PASS] D3 (both NaN)
# >>> ✅ ALL RATIOS MATCH
#
# === Debug: B3 components ===
#   Lợi nhuận trước thuế: 4474760000000.0
#   Chi phí lãi vay: nan
#
# ===== TEST ACB - Year 2022 - Q3 =====
# Testing A1...
# [PASS] A1 (both NaN)
# Testing A2...
# [PASS] A2 (both NaN)
# Testing A3...
# [PASS] A3 (both NaN)
# Testing B1...
# [PASS] B1
# Testing B2...
# [PASS] B2
# Testing B3...
# [PASS] B3 (both NaN)
# Testing C1...
# [PASS] C1 (both NaN)
# Testing C2...
# [PASS] C2 (both NaN)
# Testing C3...
# [PASS] C3 (both NaN)
# Testing D1...
# [PASS] D1 (both NaN)
# Testing D2...
# [FAIL] D2
#        Calculated : 0.007974782666338776
#        Original   : nan
#        Diff       : nan
# Testing D3...
# [PASS] D3
# >>> ❌ SOME RATIOS FAILED
#
# === Debug: B3 components ===
#   Lợi nhuận trước thuế: 5035481000000.0
#   Chi phí lãi vay: nan
#
# ===== TEST ACB - Year 2023 - Q3 =====
# Testing A1...
# [PASS] A1 (both NaN)
# Testing A2...
# [PASS] A2 (both NaN)
# Testing A3...
# [PASS] A3 (both NaN)
# Testing B1...
# [PASS] B1
# Testing B2...
# [PASS] B2
# Testing B3...
# [PASS] B3 (both NaN)
# Testing C1...
# [PASS] C1 (both NaN)
# Testing C2...
# [PASS] C2 (both NaN)
# Testing C3...
# [PASS] C3 (both NaN)
# Testing D1...
# [PASS] D1 (both NaN)
# Testing D2...
# [FAIL] D2
#        Calculated : 0.00776469365377713
#        Original   : nan
#        Diff       : nan
# Testing D3...
# [PASS] D3
# >>> ❌ SOME RATIOS FAILED
#
# === Debug: B3 components ===
#   Lợi nhuận trước thuế: 4844044000000.0
#   Chi phí lãi vay: nan
#
# ===== TEST ACB - Year 2024 - Q3 =====
# Testing A1...
# [PASS] A1 (both NaN)
# Testing A2...
# [PASS] A2 (both NaN)
# Testing A3...
# [PASS] A3 (both NaN)
# Testing B1...
# [PASS] B1
# Testing B2...
# [PASS] B2
# Testing B3...
# [PASS] B3 (both NaN)
# Testing C1...
# [PASS] C1 (both NaN)
# Testing C2...
# [PASS] C2 (both NaN)
# Testing C3...
# [PASS] C3 (both NaN)
# Testing D1...
# [PASS] D1 (both NaN)
# Testing D2...
# [FAIL] D2
#        Calculated : 0.00623113983021317
#        Original   : nan
#        Diff       : nan
# Testing D3...
# [PASS] D3
# >>> ❌ SOME RATIOS FAILED
#
# === Debug: B3 components ===
#   Lợi nhuận trước thuế: 5381796000000.0
#   Chi phí lãi vay: nan
#
# ===== TEST ACB - Year 2025 - Q3 =====
# Testing A1...
# [PASS] A1 (both NaN)
# Testing A2...
# [PASS] A2 (both NaN)
# Testing A3...
# [PASS] A3 (both NaN)
# Testing B1...
# [PASS] B1
# Testing B2...
# [PASS] B2
# Testing B3...
# [PASS] B3 (both NaN)
# Testing C1...
# [PASS] C1 (both NaN)
# Testing C2...
# [PASS] C2 (both NaN)
# Testing C3...
# [PASS] C3 (both NaN)
# Testing D1...
# [PASS] D1 (both NaN)
# Testing D2...
# [FAIL] D2
#        Calculated : 0.005673713220325437
#        Original   : nan
#        Diff       : nan
# Testing D3...
# [PASS] D3
# >>> ❌ SOME RATIOS FAILED
#
# === Debug: B3 components ===
#   Lợi nhuận trước thuế: nan
#   Chi phí lãi vay: nan
#
# ===== TEST ACB - Year 2026 - Q3 =====
# Testing A1...
# [PASS] A1 (both NaN)
# Testing A2...
# [PASS] A2 (both NaN)
# Testing A3...
# [PASS] A3 (both NaN)
# Testing B1...
# [PASS] B1 (both NaN)
# Testing B2...
# [PASS] B2 (both NaN)
# Testing B3...
# [PASS] B3 (both NaN)
# Testing C1...
# [PASS] C1 (both NaN)
# Testing C2...
# [PASS] C2 (both NaN)
# Testing C3...
# [PASS] C3 (both NaN)
# Testing D1...
# [PASS] D1 (both NaN)
# Testing D2...
# [PASS] D2 (both NaN)
# Testing D3...
# [PASS] D3 (both NaN)
# >>> ✅ ALL RATIOS MATCH
#
# === Debug: B3 components ===
#   Lợi nhuận trước thuế: 5252320000000.0
#   Chi phí lãi vay: -3036936000000.0
#
# ===== TEST VIC - Year 2022 - Q3 =====
# Testing A1...
# [PASS] A1
# Testing A2...
# [PASS] A2
# Testing A3...
# [PASS] A3
# Testing B1...
# [PASS] B1
# Testing B2...
# [PASS] B2
# Testing B3...
# [FAIL] B3
#        Calculated : -1.7294799758704167
#        Original   : -2.729479975870417
#        Diff       : 1.0000000000000002
# Testing C1...
# [FAIL] C1
#        Calculated : -0.2508274399915777
#        Original   : 0.2508274399915777
#        Diff       : -0.5016548799831554
# Testing C2...
# [PASS] C2
# Testing C3...
# [PASS] C3
# Testing D1...
# [PASS] D1
# Testing D2...
# [FAIL] D2
#        Calculated : 0.00945391289193187
#        Original   : 0.014920245560613901
#        Diff       : -0.005466332668682031
# Testing D3...
# [PASS] D3
# >>> ❌ SOME RATIOS FAILED
#
# === Debug: B3 components ===
#   Lợi nhuận trước thuế: 4475332000000.0
#   Chi phí lãi vay: -5504380000000.0
#
# ===== TEST VIC - Year 2023 - Q3 =====
# Testing A1...
# [PASS] A1
# Testing A2...
# [PASS] A2
# Testing A3...
# [PASS] A3
# Testing B1...
# [PASS] B1
# Testing B2...
# [PASS] B2
# Testing B3...
# [FAIL] B3
#        Calculated : -0.8130492444198983
#        Original   : -1.8130492444198982
#        Diff       : 0.9999999999999999
# Testing C1...
# [FAIL] C1
#        Calculated : -0.3941728985036787
#        Original   : 0.3941728985036787
#        Diff       : -0.7883457970073574
# Testing C2...
# [PASS] C2
# Testing C3...
# [PASS] C3
# Testing D1...
# [PASS] D1
# Testing D2...
# [FAIL] D2
#        Calculated : 0.007156096195070912
#        Original   : 0.015957649414859842
#        Diff       : -0.00880155321978893
# Testing D3...
# [PASS] D3
# >>> ❌ SOME RATIOS FAILED
#
# === Debug: B3 components ===
#   Lợi nhuận trước thuế: 4705397000000.0
#   Chi phí lãi vay: -5608268000000.0
#
# ===== TEST VIC - Year 2024 - Q3 =====
# Testing A1...
# [PASS] A1
# Testing A2...
# [PASS] A2
# Testing A3...
# [PASS] A3
# Testing B1...
# [PASS] B1
# Testing B2...
# [PASS] B2
# Testing B3...
# [FAIL] B3
#        Calculated : -0.8390107248797668
#        Original   : -1.839010724879767
#        Diff       : 1.0
# Testing C1...
# [FAIL] C1
#        Calculated : -0.355741950810263
#        Original   : 0.355741950810263
#        Diff       : -0.711483901620526
# Testing C2...
# [PASS] C2
# Testing C3...
# [PASS] C3
# Testing D1...
# [PASS] D1
# Testing D2...
# [FAIL] D2
#        Calculated : 0.005945106640175131
#        Original   : 0.013030959614256108
#        Diff       : -0.007085852974080977
# Testing D3...
# [PASS] D3
# >>> ❌ SOME RATIOS FAILED
#
# === Debug: B3 components ===
#   Lợi nhuận trước thuế: 4024377000000.0
#   Chi phí lãi vay: -9027158000000.0
#
# ===== TEST VIC - Year 2025 - Q3 =====
# Testing A1...
# [PASS] A1
# Testing A2...
# [PASS] A2
# Testing A3...
# [PASS] A3
# Testing B1...
# [PASS] B1
# Testing B2...
# [PASS] B2
# Testing B3...
# [FAIL] B3
#        Calculated : -0.445807750346233
#        Original   : -1.445807750346233
#        Diff       : 1.0
# Testing C1...
# [FAIL] C1
#        Calculated : -0.232274883276251
#        Original   : 0.232274883276251
#        Diff       : -0.464549766552502
# Testing C2...
# [PASS] C2
# Testing C3...
# [PASS] C3
# Testing D1...
# [PASS] D1
# Testing D2...
# [FAIL] D2
#        Calculated : 0.003699316828041982
#        Original   : 0.011997326059978702
#        Diff       : -0.00829800923193672
# Testing D3...
# [PASS] D3
# >>> ❌ SOME RATIOS FAILED
#
# === Debug: B3 components ===
#   Lợi nhuận trước thuế: nan
#   Chi phí lãi vay: nan
#
# ===== TEST VIC - Year 2026 - Q3 =====
# Testing A1...
# [PASS] A1 (both NaN)
# Testing A2...
# [PASS] A2 (both NaN)
# Testing A3...
# [PASS] A3 (both NaN)
# Testing B1...
# [PASS] B1 (both NaN)
# Testing B2...
# [PASS] B2 (both NaN)
# Testing B3...
# [PASS] B3 (both NaN)
# Testing C1...
# [PASS] C1 (both NaN)
# Testing C2...
# [PASS] C2 (both NaN)
# Testing C3...
# [PASS] C3 (both NaN)
# Testing D1...
# [PASS] D1 (both NaN)
# Testing D2...
# [PASS] D2 (both NaN)
# Testing D3...
# [PASS] D3 (both NaN)
# >>> ✅ ALL RATIOS MATCH
#
# === Debug: B3 components ===
#   Lợi nhuận trước thuế: 18948683000000.0
#   Chi phí lãi vay: -724530000000.0
#
# ===== TEST VHM - Year 2022 - Q3 =====
# Testing A1...
# [PASS] A1
# Testing A2...
# [PASS] A2
# Testing A3...
# [PASS] A3
# Testing B1...
# [PASS] B1
# Testing B2...
# [PASS] B2
# Testing B3...
# [FAIL] B3
#        Calculated : -26.153068886036465
#        Original   : -27.153068886036465
#        Diff       : 1.0
# Testing C1...
# [FAIL] C1
#        Calculated : -0.1556489063701346
#        Original   : 0.1556489063701346
#        Diff       : -0.3112978127402692
# Testing C2...
# [PASS] C2
# Testing C3...
# [PASS] C3
# Testing D1...
# [PASS] D1
# Testing D2...
# [FAIL] D2
#        Calculated : 0.05547018619357077
#        Original   : 0.05759116811103848
#        Diff       : -0.002120981917467714
# Testing D3...
# [PASS] D3
# >>> ❌ SOME RATIOS FAILED
#
# === Debug: B3 components ===
#   Lợi nhuận trước thuế: 14206184000000.0
#   Chi phí lãi vay: -716341000000.0
#
# ===== TEST VHM - Year 2023 - Q3 =====
# Testing A1...
# [PASS] A1
# Testing A2...
# [PASS] A2
# Testing A3...
# [PASS] A3
# Testing B1...
# [PASS] B1
# Testing B2...
# [PASS] B2
# Testing B3...
# [FAIL] B3
#        Calculated : -19.831594170932558
#        Original   : -20.831594170932558
#        Diff       : 1.0
# Testing C1...
# [FAIL] C1
#        Calculated : -0.32205065207966893
#        Original   : 0.32205065207966893
#        Diff       : -0.6441013041593379
# Testing C2...
# [PASS] C2
# Testing C3...
# [PASS] C3
# Testing D1...
# [PASS] D1
# Testing D2...
# [FAIL] D2
#        Calculated : 0.0340643629336632
#        Original   : 0.03578204445941729
#        Diff       : -0.0017176815257540848
# Testing D3...
# [PASS] D3
# >>> ❌ SOME RATIOS FAILED
#
# === Debug: B3 components ===
#   Lợi nhuận trước thuế: 10836621000000.0
#   Chi phí lãi vay: -1508326000000.0
#
# ===== TEST VHM - Year 2024 - Q3 =====
# Testing A1...
# [PASS] A1
# Testing A2...
# [PASS] A2
# Testing A3...
# [PASS] A3
# Testing B1...
# [PASS] B1
# Testing B2...
# [PASS] B2
# Testing B3...
# [FAIL] B3
#        Calculated : -7.184535040833348
#        Original   : -8.184535040833348
#        Diff       : 1.0
# Testing C1...
# [FAIL] C1
#        Calculated : -0.4061727799202019
#        Original   : 0.4061727799202019
#        Diff       : -0.8123455598404038
# Testing C2...
# [PASS] C2
# Testing C3...
# [PASS] C3
# Testing D1...
# [PASS] D1
# Testing D2...
# [FAIL] D2
#        Calculated : 0.02065360050989285
#        Original   : 0.02352833080106799
#        Diff       : -0.0028747302911751385
# Testing D3...
# [PASS] D3
# >>> ❌ SOME RATIOS FAILED
#
# === Debug: B3 components ===
#   Lợi nhuận trước thuế: 5420373000000.0
#   Chi phí lãi vay: -2699135000000.0
#
# ===== TEST VHM - Year 2025 - Q3 =====
# Testing A1...
# [PASS] A1
# Testing A2...
# [PASS] A2
# Testing A3...
# [PASS] A3
# Testing B1...
# [PASS] B1
# Testing B2...
# [PASS] B2
# Testing B3...
# [FAIL] B3
#        Calculated : -2.00818891978356
#        Original   : -3.00818891978356
#        Diff       : 1.0
# Testing C1...
# [FAIL] C1
#        Calculated : -0.11102165115017068
#        Original   : 0.11102165115017068
#        Diff       : -0.22204330230034136
# Testing C2...
# [PASS] C2
# Testing C3...
# [PASS] C3
# Testing D1...
# [PASS] D1
# Testing D2...
# [FAIL] D2
#        Calculated : 0.0070553469880055755
#        Original   : 0.010568635463258189
#        Diff       : -0.003513288475252613
# Testing D3...
# [PASS] D3
# >>> ❌ SOME RATIOS FAILED
#
# === Debug: B3 components ===
#   Lợi nhuận trước thuế: nan
#   Chi phí lãi vay: nan
#
# ===== TEST VHM - Year 2026 - Q3 =====
# Testing A1...
# [PASS] A1 (both NaN)
# Testing A2...
# [PASS] A2 (both NaN)
# Testing A3...
# [PASS] A3 (both NaN)
# Testing B1...
# [PASS] B1 (both NaN)
# Testing B2...
# [PASS] B2 (both NaN)
# Testing B3...
# [PASS] B3 (both NaN)
# Testing C1...
# [PASS] C1 (both NaN)
# Testing C2...
# [PASS] C2 (both NaN)
# Testing C3...
# [PASS] C3 (both NaN)
# Testing D1...
# [PASS] D1 (both NaN)
# Testing D2...
# [PASS] D2 (both NaN)
# Testing D3...
# [PASS] D3 (both NaN)
# >>> ✅ ALL RATIOS MATCH
#
# === Debug: B3 components ===
#   Lợi nhuận trước thuế: 6673383000000.0
#   Chi phí lãi vay: nan
#
# ===== TEST BID - Year 2022 - Q3 =====
# Testing A1...
# [PASS] A1 (both NaN)
# Testing A2...
# [PASS] A2 (both NaN)
# Testing A3...
# [PASS] A3 (both NaN)
# Testing B1...
# [PASS] B1
# Testing B2...
# [PASS] B2
# Testing B3...
# [PASS] B3 (both NaN)
# Testing C1...
# [PASS] C1 (both NaN)
# Testing C2...
# [PASS] C2 (both NaN)
# Testing C3...
# [PASS] C3 (both NaN)
# Testing D1...
# [PASS] D1 (both NaN)
# Testing D2...
# [FAIL] D2
#        Calculated : 0.0032569726677314182
#        Original   : nan
#        Diff       : nan
# Testing D3...
# [PASS] D3
# >>> ❌ SOME RATIOS FAILED
#
# === Debug: B3 components ===
#   Lợi nhuận trước thuế: 5892788000000.0
#   Chi phí lãi vay: nan
#
# ===== TEST BID - Year 2023 - Q3 =====
# Testing A1...
# [PASS] A1 (both NaN)
# Testing A2...
# [PASS] A2 (both NaN)
# Testing A3...
# [PASS] A3 (both NaN)
# Testing B1...
# [PASS] B1
# Testing B2...
# [PASS] B2
# Testing B3...
# [PASS] B3 (both NaN)
# Testing C1...
# [PASS] C1 (both NaN)
# Testing C2...
# [PASS] C2 (both NaN)
# Testing C3...
# [PASS] C3 (both NaN)
# Testing D1...
# [PASS] D1 (both NaN)
# Testing D2...
# [FAIL] D2
#        Calculated : 0.0027628644088283755
#        Original   : nan
#        Diff       : nan
# Testing D3...
# [PASS] D3
# >>> ❌ SOME RATIOS FAILED
#
# === Debug: B3 components ===
#   Lợi nhuận trước thuế: 6498279000000.0
#   Chi phí lãi vay: nan
#
# ===== TEST BID - Year 2024 - Q3 =====
# Testing A1...
# [PASS] A1 (both NaN)
# Testing A2...
# [PASS] A2 (both NaN)
# Testing A3...
# [PASS] A3 (both NaN)
# Testing B1...
# [PASS] B1
# Testing B2...
# [PASS] B2
# Testing B3...
# [PASS] B3 (both NaN)
# Testing C1...
# [PASS] C1 (both NaN)
# Testing C2...
# [PASS] C2 (both NaN)
# Testing C3...
# [PASS] C3 (both NaN)
# Testing D1...
# [PASS] D1 (both NaN)
# Testing D2...
# [FAIL] D2
#        Calculated : 0.002522642172544519
#        Original   : nan
#        Diff       : nan
# Testing D3...
# [PASS] D3
# >>> ❌ SOME RATIOS FAILED
#
# === Debug: B3 components ===
#   Lợi nhuận trước thuế: 7593776000000.0
#   Chi phí lãi vay: nan
#
# ===== TEST BID - Year 2025 - Q3 =====
# Testing A1...
# [PASS] A1 (both NaN)
# Testing A2...
# [PASS] A2 (both NaN)
# Testing A3...
# [PASS] A3 (both NaN)
# Testing B1...
# [PASS] B1
# Testing B2...
# [PASS] B2
# Testing B3...
# [PASS] B3 (both NaN)
# Testing C1...
# [PASS] C1 (both NaN)
# Testing C2...
# [PASS] C2 (both NaN)
# Testing C3...
# [PASS] C3 (both NaN)
# Testing D1...
# [PASS] D1 (both NaN)
# Testing D2...
# [FAIL] D2
#        Calculated : 0.0024719562741486963
#        Original   : nan
#        Diff       : nan
# Testing D3...
# [PASS] D3
# >>> ❌ SOME RATIOS FAILED
#
# === Debug: B3 components ===
#   Lợi nhuận trước thuế: nan
#   Chi phí lãi vay: nan
#
# ===== TEST BID - Year 2026 - Q3 =====
# Testing A1...
# [PASS] A1 (both NaN)
# Testing A2...
# [PASS] A2 (both NaN)
# Testing A3...
# [PASS] A3 (both NaN)
# Testing B1...
# [PASS] B1 (both NaN)
# Testing B2...
# [PASS] B2 (both NaN)
# Testing B3...
# [PASS] B3 (both NaN)
# Testing C1...
# [PASS] C1 (both NaN)
# Testing C2...
# [PASS] C2 (both NaN)
# Testing C3...
# [PASS] C3 (both NaN)
# Testing D1...
# [PASS] D1 (both NaN)
# Testing D2...
# [PASS] D2 (both NaN)
# Testing D3...
# [PASS] D3 (both NaN)
# >>> ✅ ALL RATIOS MATCH
#
# === Debug: B3 components ===
#   Lợi nhuận trước thuế: 4156564000000.0
#   Chi phí lãi vay: nan
#
# ===== TEST CTG - Year 2022 - Q3 =====
# Testing A1...
# [PASS] A1 (both NaN)
# Testing A2...
# [PASS] A2 (both NaN)
# Testing A3...
# [PASS] A3 (both NaN)
# Testing B1...
# [PASS] B1
# Testing B2...
# [PASS] B2
# Testing B3...
# [PASS] B3 (both NaN)
# Testing C1...
# [PASS] C1 (both NaN)
# Testing C2...
# [PASS] C2 (both NaN)
# Testing C3...
# [PASS] C3 (both NaN)
# Testing D1...
# [PASS] D1 (both NaN)
# Testing D2...
# [FAIL] D2
#        Calculated : 0.002374108226869565
#        Original   : nan
#        Diff       : nan
# Testing D3...
# [PASS] D3
# >>> ❌ SOME RATIOS FAILED
#
# === Debug: B3 components ===
#   Lợi nhuận trước thuế: 4870950000000.0
#   Chi phí lãi vay: nan
#
# ===== TEST CTG - Year 2023 - Q3 =====
# Testing A1...
# [PASS] A1 (both NaN)
# Testing A2...
# [PASS] A2 (both NaN)
# Testing A3...
# [PASS] A3 (both NaN)
# Testing B1...
# [PASS] B1
# Testing B2...
# [PASS] B2
# Testing B3...
# [PASS] B3 (both NaN)
# Testing C1...
# [PASS] C1 (both NaN)
# Testing C2...
# [PASS] C2 (both NaN)
# Testing C3...
# [PASS] C3 (both NaN)
# Testing D1...
# [PASS] D1 (both NaN)
# Testing D2...
# [FAIL] D2
#        Calculated : 0.0025794901331490498
#        Original   : nan
#        Diff       : nan
# Testing D3...
# [PASS] D3
# >>> ❌ SOME RATIOS FAILED
#
# === Debug: B3 components ===
#   Lợi nhuận trước thuế: 6552679000000.0
#   Chi phí lãi vay: nan
#
# ===== TEST CTG - Year 2024 - Q3 =====
# Testing A1...
# [PASS] A1 (both NaN)
# Testing A2...
# [PASS] A2 (both NaN)
# Testing A3...
# [PASS] A3 (both NaN)
# Testing B1...
# [PASS] B1
# Testing B2...
# [PASS] B2
# Testing B3...
# [PASS] B3 (both NaN)
# Testing C1...
# [PASS] C1 (both NaN)
# Testing C2...
# [PASS] C2 (both NaN)
# Testing C3...
# [PASS] C3 (both NaN)
# Testing D1...
# [PASS] D1 (both NaN)
# Testing D2...
# [FAIL] D2
#        Calculated : 0.0029386963503775488
#        Original   : nan
#        Diff       : nan
# Testing D3...
# [PASS] D3
# >>> ❌ SOME RATIOS FAILED
#
# === Debug: B3 components ===
#   Lợi nhuận trước thuế: 10614390000000.0
#   Chi phí lãi vay: nan
#
# ===== TEST CTG - Year 2025 - Q3 =====
# Testing A1...
# [PASS] A1 (both NaN)
# Testing A2...
# [PASS] A2 (both NaN)
# Testing A3...
# [PASS] A3 (both NaN)
# Testing B1...
# [PASS] B1
# Testing B2...
# [PASS] B2
# Testing B3...
# [PASS] B3 (both NaN)
# Testing C1...
# [PASS] C1 (both NaN)
# Testing C2...
# [PASS] C2 (both NaN)
# Testing C3...
# [PASS] C3 (both NaN)
# Testing D1...
# [PASS] D1 (both NaN)
# Testing D2...
# [FAIL] D2
#        Calculated : 0.0038436336096292567
#        Original   : nan
#        Diff       : nan
# Testing D3...
# [PASS] D3
# >>> ❌ SOME RATIOS FAILED
#
# === Debug: B3 components ===
#   Lợi nhuận trước thuế: nan
#   Chi phí lãi vay: nan
#
# ===== TEST CTG - Year 2026 - Q3 =====
# Testing A1...
# [PASS] A1 (both NaN)
# Testing A2...
# [PASS] A2 (both NaN)
# Testing A3...
# [PASS] A3 (both NaN)
# Testing B1...
# [PASS] B1 (both NaN)
# Testing B2...
# [PASS] B2 (both NaN)
# Testing B3...
# [PASS] B3 (both NaN)
# Testing C1...
# [PASS] C1 (both NaN)
# Testing C2...
# [PASS] C2 (both NaN)
# Testing C3...
# [PASS] C3 (both NaN)
# Testing D1...
# [PASS] D1 (both NaN)
# Testing D2...
# [PASS] D2 (both NaN)
# Testing D3...
# [PASS] D3 (both NaN)
# >>> ✅ ALL RATIOS MATCH
